# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# importing all libraries needed for the codes below

# %%
# Question 1

# %%
# Question 2

# %%
# Question 3

x1=pd.Series(np.random.randint(1,4,size=100))
x2=pd.Series(np.random.randint(1,3,size=100))
x3=pd.Series(np.random.randint(10000,30000,size=100))
# creating 3 series of lenght 100
# series x1 has random numebrs between 1-4
# series x2 has random numebrs between 1-3
# series x3 has random numebrs between 10000-30000
df_combined=pd.concat([x1,x2,x3],axis=1)
# creating dataframe by joining seriesies by column 
columns_combined_df=['bedrs', 'bathrs', 'price_sqr_meter']
# assigning names of columns 
df_combined.columns=columns_combined_df
df_combined

# the index 99 is right as pythons is a zero index, starting at zero not one.
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       1            16462
# 1       2       1            15039
# 2       3       1            26603
# 3       3       1            21942
# 4       3       2            19890
# ..    ...     ...              ...
# 95      1       2            19007
# 96      3       1            11855
# 97      1       1            29561
# 98      1       2            21959
# 99      2       1            17106
#
# [100 rows x 3 columns]

# %%
# Question 4

# %%
# Question 5

# %%
# Question 6
df_mar=pd.read_csv("us-marriages-divorces-1867-2014.csv")
mar=[]
div=[]
# creating arrays
for i in range(len(df_mar)):
    a=df_mar["Marriages"][i]/df_mar["Population"][i]
    b=df_mar["Divorces"][i]/df_mar["Population"][i]
    mar.append(a)
    div.append(b)
# count percentages of mar and div over population and append to the array    

plt.plot(df_mar["Year"],mar,label="Marriages")
plt.plot(df_mar["Year"],div,label="Divorces")

# graphing mar and div 

plt.legend() # adding a legend
# Setting axis titltes and graph title 

plt.xlabel("Year")
plt.ylabel("percentage per capita")
plt.title("Marriages and Divorces Per capita In the U.S")
# Out:
# Text(0.5, 1.0, 'Marriages and Divorces Per capita In the U.S')

# %%
# Question 7
df_mar=pd.read_csv("us-marriages-divorces-1867-2014.csv")

mar1900=[]
div1900=[]
mar1950=[]
div1950=[]
mar2000=[]
div2000=[]
# creating arrays for each category 

# line/s to cont numbers if it lies in specific year then append it to the proper array


plt.bar(year,mar****)
# a line to select the array and create a bar for specific year and graph it 
plt.xlabel("Years")
plt.ylabel("Number of Marriages")
plt.title('Number of Marriages in Selected Years')
# naming axises and title for marraiges chart


plt.bar(year,div****)
# a line to select the array and create a bar for specific year and graph it 
plt.xlabel("Years")
plt.ylabel("Number of Divorces")
plt.title('Number of Divorces in Selected Years')
# naming axises and title for divorces chart
# Out:
#   File "<ipython-input-25-d2a2eacb0405>", line 15
#     plt.bar(year,mar****)
#                       ^
# SyntaxError: invalid syntax

# %%
# Question 8
data = pd.read_csv("actor_kill_counts.csv")
# open the file 
new = data.sort_values(by='Count',ascending=False )
# sort descending by column count 
new.plot(x ='Actor', y='Count', kind = 'barh')
# Out:
# <AxesSubplot:ylabel='Actor'>

# %%
# Question 9
df_roman=pd.read_csv("roman-emperor-reigns.csv")
# reading csv file 
length_re=[] 
label_em=[] 
# creating arrays for reign and emperiors 
for i in range(len(df_roman)):
    if df_roman["Cause_of_Death"][i]=="Assassinated":
        label_em.append(df_roman["Emperor"][i])
        length_re.append(df_roman["Length_of_Reign"][i])
        # retreiving emperior if cause of death = "Assassinated", then add the name to em and reign to re
plt.figure(figsize=(20,15))
# setting pie chart size and creating it
#plt.pie(length_re, labels = label_em,autopct='%1f%%')
# percentage set to 1 decimal place for better view 
plt.pie(length_re, labels = label_em,autopct='%1.1f%%')

plt.title('Fractions of Assasinated Roman Emeprors')
# Adding title then graphing
plt.show()

# %%
# Question 10
df_scp=pd.read_csv("arcade-revenue-vs-cs-doctorates.csv")
# open the file 

plt.scatter(df_scp["Total Arcade Revenue (billions)"], df_scp["Computer Science Doctorates Awarded (US)"])
# graphing selected columns from the csv 
plt.xlabel("Total Revenue In Billions Earned by Arcades")
# adding axis x title 
plt.ylabel("Number of Awarded Computer Science PhDs")
# adding axis y title 
plt.title ('Total Revenue Earned by Arcades and Number of Awarded Computer Science PhDs')
# addding a title for the graph
# Out:
# Text(0.5, 1.0, 'Total Revenue Earned by Arcades and Number of Awarded Computer Science PhDs')
